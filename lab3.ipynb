# %% [markdown]
# ### Вариант 18

# %%
# 1.Постройте в одном окне графики двух функции y1(x) и y2(x), 𝑥 ∈ [0,2𝜋], ∆𝑥 = 0,2. При
# построении графиков вид функций и параметры выбрать согласно варианту. Толщину
# линии, размер и цвет маркера, а также контура маркера подобрать самостоятельно.
# 2. Постройте один из графиков функций для вашего варианта (y1 или y2), используйте для
# построения не менее 500 точек.
# 3. Подберите наилучший вариант маркировки (на основе визуализации и сравнения
# нескольких вариантов).
# 4. Продемонстрируйте навыки построения графиков с заливкой (2-3 варианта).
# 5. Продемонстрируйте навыки обрезки графика (ограничения для обрезки придумайте
# самостоятельно).
# y1(x)= √𝑥^3,  y2(x)= 2,5𝑠𝑖𝑛^2(𝑥)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Задаем функции
def y1(x):
    return np.sqrt(x**3)

def y2(x):
    return  2.5*np.sin(x)**2

# Задаем значения x
x=np.arange(0,2*np.pi,0.2)

plt.figure(figsize=(10,6))

# График y1
plt.plot(x, y1(x), label='$y_1(x)=\sqrt{x^3}$', color='pink', linewidth=1, linestyle='--')

# График y2
plt.plot(x, y2(x), label='$y_2(x)=2.5sin^2(x)$', color='lime', linewidth=1, linestyle='-.')
# Добавляем маркеры
plt.scatter(x, y1(x), color='pink', s=20, marker='o', edgecolors='black')
plt.scatter(x, y2(x), color='lime', s=40, marker='x', edgecolors='black')
# Настройки графика
plt.xlabel('x')
plt.ylabel('y')
plt.title('Графики функций $y_1(x)$ и $y_2(x)$')
plt.legend()
plt.grid(True)
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\s'
# <>:17: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\28158\AppData\Local\Temp\ipykernel_23916\4133630052.py:17: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x, y1(x), label='$y_1(x)=\sqrt{x^3}$', color='pink', linewidth=1, linestyle='--')
# C:\Users\28158\AppData\Local\Temp\ipykernel_23916\4133630052.py:23: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x, y2(x), color='lime', s=40, marker='x', edgecolors='black')

# %%
# 2. Постройте один из графиков функций для вашего варианта (y1 или y2), используйте для
# построения не менее 500 точек.
import numpy as np
import matplotlib.pyplot as plt

# Определяем функцию y1(x)
def y1(x):
    return np.sqrt(x**3)

# Создаем 500 точек в диапазоне от 0 до 2*pi
x_values = np.arange(0.0, 5, 0.01)

# Вычисляем значения y1 для каждой точки x
y_values = y1(x_values)

# Строим график
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='$y_1(x)=\sqrt{x^3}$', color='blue')
plt.title('График функции $y_1(x)=\sqrt{x^3}$ с 500 точками')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\s'
# <>:19: SyntaxWarning: invalid escape sequence '\s'
# <>:18: SyntaxWarning: invalid escape sequence '\s'
# <>:19: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\28158\AppData\Local\Temp\ipykernel_23916\2316510897.py:18: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x_values, y_values, label='$y_1(x)=\sqrt{x^3}$', color='blue')
# C:\Users\28158\AppData\Local\Temp\ipykernel_23916\2316510897.py:19: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('График функции $y_1(x)=\sqrt{x^3}$ с 500 точками')

# %%
# 3. Подберите наилучший вариант маркировки (на основе визуализации и сравнения
# нескольких вариантов.
import numpy as np
import matplotlib.pyplot as plt

# Определим функцию y1(x)
def y1(x):
    return np.sqrt(x**3)

# Создадим набор данных
x_values = np.linspace(0, 2*np.pi, 50)
y_values = y1(x_values)

# Зададим размеры графика
plt.figure(figsize=(15, 5))

# Стиль 1: круглые маркеры, синий цвет
plt.subplot(1, 3, 1)
plt.plot(x_values, y_values, marker='o', color='blue', linestyle='', label='Стиль 1')
plt.title('Стиль 1')
plt.legend()

# Стиль 2: крестиковые маркеры, красный цвет
plt.subplot(1, 3, 2)
plt.plot(x_values, y_values, marker='x', color='red', linestyle='', label='Стиль 2')
plt.title('Стиль 2')
plt.legend()

# Стиль 3: треугольные маркеры, зеленый цвет
plt.subplot(1, 3, 3)
plt.plot(x_values, y_values, marker='^', color='green', linestyle='', label='Стиль 3')
plt.title('Стиль 3')
plt.legend()

# Подгоняем компоновку
plt.tight_layout()

# Отображаем графики
plt.show()

# %%
# 4. Продемонстрируйте навыки построения графиков с заливкой (2-3 варианта).
import numpy as np
import matplotlib.pyplot as plt

# Определяем функцию y1(x)
def y1(x):
    return np.sqrt(x**3)

# Создаем данные
x_values = np.linspace(0, 2*np.pi, 100)
y_values = y1(x_values)

# Создаем график
plt.figure(figsize=(10, 6))

# Вариант 1: Заполнение всей области под графиком одним цветом
plt.subplot(2, 2, 1)
plt.plot(x_values, y_values, color='blue', label='Функция y1(x)')
plt.fill_between(x_values, y_values, color='lightblue', alpha=0.3)
plt.title('Заполнение всей области')
plt.legend()

# Вариант 2: Использование двух разных цветов для заливки между графиком и осью X
plt.subplot(2, 2, 2)
plt.plot(x_values, y_values, color='red', label='Функция y1(x)')
plt.fill_between(x_values, y_values, color='pink', alpha=0.3)
plt.title('Заливка между графиком и осью X')
plt.legend()

# Вариант 3: Заливка определенной области под графиком, чтобы выделить или подчеркнуть данные
plt.subplot(2, 2, 3)
plt.plot(x_values, y_values, color='green', label='Функция y1(x)')
plt.fill_between(x_values, y_values, where=(x_values < np.pi), color='lightgreen', alpha=0.3)
plt.title('Заливка определенной области')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 5. Продемонстрируйте навыки обрезки графика (ограничения для обрезки придумайте
# самостоятельно).import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt

# Создание примера данных
x = np.linspace(0, 10, 100)
y = np.sin(x)

y_masked=np.ma.masked_where(y<0,y)
plt.ylim(-1,1)
plt.plot(x,y_masked,linewidth=3)
