# %% [markdown]
# ### Вариант 18

# %%
# y = √3𝑥 − 2𝑠𝑖𝑛 x

# %%
# 1. Выберите функцию по номеру варианта.
# 2. Постройте график функции. График должен содержать заголовок и подписи осей.
# 3. Скопируйте код для построения графика и измените внешний вид заголовка и подписей осей, используя необходимые параметры.
# 4. Используя аннотацию – выделите: локальный минимум (или максимум) функции, точку разрыва, точку перегиба. Используйте разные типы стрелок.
# 5. Добавьте на график надпись (текст придумайте самостоятельно). 
# 6. Добавьте еще один график (любой), оформите легенду.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Определение функции
def fun(x):
    return np.sqrt(3)*x-2*np.sin(x)

# Определение диапазона значений x от 0 до π с шагом 0.01
x_values = np.arange(-2*np.pi, 2*np.pi, 0.1)
# Вычисление значений y
y=fun(x_values)

# Построение графика
plt.figure(figsize=(8,6))
plt.plot(x_values, y, label='$y(x) = \sqrt{3}x - 2\sin(x)$')
plt.title("График функции $y(x) = \sqrt{3}x - 2\sin(x)$")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\28158\AppData\Local\Temp\ipykernel_20076\1486126474.py:14: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x_values, y, label='$y(x) = \sqrt{3}x - 2\sin(x)$')
# C:\Users\28158\AppData\Local\Temp\ipykernel_20076\1486126474.py:15: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("График функции $y(x) = \sqrt{3}x - 2\sin(x)$")
# Text(0, 0.5, 'y')

# %% [markdown]
# #### Скопируйте код для построения графика и измените внешний вид заголовка и подписей осей, используя необходимые параметры.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Определение функции
def fun(x):
    return np.sqrt(3)*x-2*np.sin(x)

# Определение диапазона значений x от 0 до π с шагом 0.01
x_values = np.arange(-2*np.pi, 2*np.pi, 0.1)
# Вычисление значений y
y=fun(x_values)

# Построение графика
plt.figure(figsize=(8,6))
plt.plot(x_values, y, label='$y(x) = \sqrt{3}x - 2\sin(x)$')
plt.title('График функции $y(x) = \sqrt{3}x - 2\sin(x)$', fontsize=16, fontweight='bold', color='blue', loc='left', pad=20)
plt.xlabel('X\nНезависимая величина', fontsize=14, fontweight='bold', color='green', labelpad=10)
plt.ylabel('Y\nЗависимая величина', fontsize=14, fontweight='bold', color='red', labelpad=10)

# Поиск локальных экстремумов
local_max_index = np.argmax(y)
local_min_index = np.argmin(y)
plt.annotate('Локальный максимум', xy=(x_values[local_max_index], y[local_max_index]), xytext=(-3, 2),
             arrowprops=dict(facecolor='pink',arrowstyle='simple'))
plt.annotate('Локальный минимум', xy=(x_values[local_min_index], y[local_min_index]), xytext=(1, -2),
             arrowprops=dict(arrowstyle='->'))

# Поиск точек разрыва и перегиба
discontinuity_points = [-np.pi, 0, np.pi]
inflection_points = [0]
plt.axvline(x=0, color='gray', linestyle='--')
plt.annotate('Точка разрыва', xy=(0, fun(0)), xytext=(-6, -1),
             arrowprops=dict(facecolor='green', arrowstyle='fancy'))
plt.annotate('Точка перегиба', xy=(0, fun(0)), xytext=(4, 2),
             arrowprops=dict(facecolor='purple', arrowstyle='-|>'))

 # Добавьте на график надпись (текст придумайте самостоятельно). 
plt.text(-6,6,'nihao',fontsize=12, bbox=dict(facecolor='lightgray', alpha=0.5))

# Добавление второго графика и легенды
plt.plot(x_values, np.cos(x_values), label='$y = \cos(x)$', linestyle='--')
plt.legend()
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:40: SyntaxWarning: invalid escape sequence '\c'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:40: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\28158\AppData\Local\Temp\ipykernel_20076\1975131338.py:14: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x_values, y, label='$y(x) = \sqrt{3}x - 2\sin(x)$')
# C:\Users\28158\AppData\Local\Temp\ipykernel_20076\1975131338.py:15: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('График функции $y(x) = \sqrt{3}x - 2\sin(x)$', fontsize=16, fontweight='bold', color='blue', loc='left', pad=20)
# C:\Users\28158\AppData\Local\Temp\ipykernel_20076\1975131338.py:40: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(x_values, np.cos(x_values), label='$y = \cos(x)$', linestyle='--')
